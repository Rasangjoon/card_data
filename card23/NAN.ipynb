# %%
import pandas as pd

# %%
df = pd.read_csv('analyzed_Df.csv')
df.head()
# Out:
#             카드이름       할인내용2  할인율2(%)                   할인내용3  할인율3(%)  \
# 0  삼성카드 taptap O        통신요금     10.0  월 최대 3만원, 연간 36만원 할인쇼핑      1.0
# 1  카드의정석 EVERY 1  온라인 신규 연회비    100.0                     NaN      NaN
# 2    삼성 iD ON 카드        이동통신     10.0  커피전문점·배달앱·델리 중많이 쓰는 영역     30.0
# 3   신한카드 Mr.Life   신규 고객 연회비    100.0                 전기·도시가스     10.0
# 4   taptap DRIVE         NaN      NaN                     편의점     10.0
#
#                            할인내용4  할인율4(%)                           할인내용5  \
# 0  커피 연 최대 12만원 할인스타벅스 50% 또는 카페     30.0  쿠팡·11번가 등 연최대 6만원할인쇼핑 7% 할인 또는
# 1                             쇼핑      1.0                             항공사
# 2         커피전문점·배달앱·델리 중많이 쓰는 영역     30.0                            스트리밍
# 3                            NaN      NaN                    SKT·KT·LG U+
# 4                          커피전문점     10.0                        온라인 간편결제
#
#    할인율5(%)          할인내용6  할인율6(%)                                 할인내용7  \
# ...

# %%
df['할인내용2'].isnull().sum()
# Out:
# 153

# %%
df['할인내용2'] = df['할인내용2'].
