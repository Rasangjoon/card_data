# %%
import pandas as pd

# %%
df = pd.read_csv('soby.csv', encoding='cp949')
df.head()
# Out:
#            날짜   카드내역      가격   분류
# 0  2023-08-01  카카오페이  10,000   이체
# 1  2023-07-31    월선네  56,000   식당
# 2  2023-07-31  카카오페이  30,400   이체
# 3  2023-07-29  은파주유소  46,000  주유소
# 4  2023-07-28    지마켓  22,890   쇼핑

# %%
card = pd.read_csv('analyzed_df.csv')
card.head()
# Out:
#             카드이름       할인내용2  할인율2(%)                   할인내용3  할인율3(%)  \
# 0  삼성카드 taptap O        통신요금     10.0  월 최대 3만원, 연간 36만원 할인쇼핑      1.0
# 1  카드의정석 EVERY 1  온라인 신규 연회비    100.0                     NaN      NaN
# 2    삼성 iD ON 카드        이동통신     10.0  커피전문점·배달앱·델리 중많이 쓰는 영역     30.0
# 3   신한카드 Mr.Life   신규 고객 연회비    100.0                 전기·도시가스     10.0
# 4   taptap DRIVE         NaN      NaN                     편의점     10.0
#
#                            할인내용4  할인율4(%)                           할인내용5  \
# 0  커피 연 최대 12만원 할인스타벅스 50% 또는 카페     30.0  쿠팡·11번가 등 연최대 6만원할인쇼핑 7% 할인 또는
# 1                             쇼핑      1.0                             항공사
# 2         커피전문점·배달앱·델리 중많이 쓰는 영역     30.0                            스트리밍
# 3                            NaN      NaN                    SKT·KT·LG U+
# 4                          커피전문점     10.0                        온라인 간편결제
#
#    할인율5(%)          할인내용6  할인율6(%)                                 할인내용7  \
# ...

# %%
card2 = pd.read_csv('card_data.csv')
card2.head()
# Out:
#             카드이름   혜택종류                 상세혜택                 상세혜택2  \
# 0  삼성카드 taptap O     통신       통신요금 10% 결제일할인      연 최대 36만원 할인 혜택!
# 1  카드의정석 EVERY 1  연회비지원  온라인 신규 연회비 100% 캐시백       전월실적 조건없이 1% 할인
# 2    삼성 iD ON 카드     통신       이동통신 10% 결제일할인     내 취향을 알아서 챙기는 카드!
# 3   신한카드 Mr.Life  연회비지원  신규 고객 연회비 100% 캐시백!  공과금, 쇼핑 등 주요혜택 10%할인
# 4   taptap DRIVE     주유    주유 리터당 최대 150원 할인   주유소 리터당 최대 150원 할인!
#
#                                       추가항목1  \
# 0     스타벅스50%,교통10%통신10%할인G마켓·옥션·11번가 7% 할인
# 1       무실적 1% + 최대 2만원 청구할인국내외 가맹점 1% 청구할인
# 2          연 최대 48만원 할인!배달앱·스트리밍·온라인간편결제 할인
# 3   공과금부터 쇼핑까지 생활혜택 10%주요 생활영역 연간 최대60만원 할인
# 4  모든주유소 리터당 최대 150원 할인온라인쇼핑온라인간편결제한도없이1%할인
#
#                                    추가항목2                               추가항목3  \
# 0                         통신요금 10% 결제일할인   월 최대 3만원, 연간 36만원 할인쇼핑 1% 빅포인트 적립
# 1                    온라인 신규 연회비 100% 캐시백    기본 할인추가할인할인 제공 시 유의사항실적 산정 방법 안내
# ...

# %%
#card.csv에 있는 혜택종류를 soby.csv데이터와 결합.
card['혜택종류'].unique()
# Out:
# array(['통신', '연회비지원', '주유', '간편결제', '쇼핑', '언제나할인', '교육', '항공마일리지', '반려동물',
#        '포인트/캐시백', '국민행복카드', '대중교통', '의료', '대형마트', '프리미엄', '카페/베이커리', '렌탈',
#        '관리비', '경차유류환급', '편의점', '외식', '오토', '체크카드겸용', '문화', '레저', '영화',
#        '바우처'], dtype=object)
